# %% [markdown]
# ## Init

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-proj-"

# For convertting the CSV string to a DataFrame
import pandas as pd
from io import StringIO

# For embedding and vector store
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma

from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
import json

from langchain.chat_models import ChatOpenAI

from langchain.chains.query_constructor.schema import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever

# %% [markdown]
# ## Generate Real Estate Listings

# %%
# Define the prompt template with a variable for the number of listings
prompt_template = """
Generate {n_listings} real estate listings. Each listing should include the following fields:
Neighborhood, Price, Bedrooms, Bathrooms, House Size, Description, and Neighborhood Description.

Please output the result in CSV format with headers.

Example listing:
Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description,Neighborhood Description
"Green Oaks","800000",3,2,"2000","Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.","Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
"""

# Create the prompt template object
prompt = PromptTemplate(
    input_variables=["n_listings"],
    template=prompt_template
)

# Initialize the OpenAI LLM with a fixed temperature for consistency
# model_name = "gpt-3.5-turbo-instruct"
model_name = "chatgpt-4o-latest"
temperature = 0
llm = ChatOpenAI(model=model_name, temperature=temperature)

# Create an LLMChain that ties the prompt and the LLM together
chain = LLMChain(llm=llm, prompt=prompt)

# Generate the listings by specifying the number of listings to generate
n_listings = 10 
response = chain.run(n_listings=n_listings)

# Check if the response is valid before printing
if response:
	# Print the CSV-formatted result
	print(response)
else:
	print("No response received from the LLM. Please check your configuration.")
# Out:
# Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description,Neighborhood Description
# "Maplewood","675000",4,3,"2400","This beautifully updated 4-bedroom, 3-bathroom home in Maplewood offers spacious living with modern finishes. The open-concept kitchen features granite countertops, stainless steel appliances, and a large island perfect for entertaining. A cozy fireplace anchors the living room, while the master suite includes a walk-in closet and spa-like bathroom. The backyard is fully fenced with a patio ideal for summer barbecues.","Maplewood is a family-friendly neighborhood known for its tree-lined streets, excellent schools, and community events. Residents enjoy weekend farmers markets, local parks, and a variety of dining options within walking distance."
#
# "Brookside","950000",5,4,"3200","This stunning 5-bedroom, 4-bathroom home in Brookside combines classic charm with modern upgrades. Featuring hardwood floors throughout, a chef’s kitchen with double ovens, and a finished basement with a home theater, this home is perfect for large families or entertaining guests. The landscaped backyard includes a pergola and fire pit.","Brookside is a historic neighborhood with a vibrant arts scene, boutique shopping, and top-rated restaurants. Its walkable streets and proximity to downtown make it a favorite among professionals and families alike."
#
# "Sunset Hills","725000",3,2.5,"2100","Enjoy panoramic views in this 3-bedroom, 2.5-bathroom home perched in Sunset Hills. The open floor plan includes a gourmet kitchen, vaulted ceilings, and a sunroom that opens to a large deck. The master suite features a private balcony and luxurious en-suite bathroom.","Sunset Hills is known for its scenic vistas, quiet streets, and upscale homes. Residents enjoy hiking trails, nearby wineries, and a peaceful suburban atmosphere just minutes from the city center."
#
# "Riverbend","580000",3,2,"1850","Charming 3-bedroom, 2-bathroom ranch-style home in Riverbend with a spacious backyard and updated kitchen. The home features a bright living room with bay windows, a formal dining area, and a two-car garage. Perfect for first-time buyers or those looking to downsize.","Riverbend is a picturesque neighborhood along the river, offering walking trails, kayaking, and picnic areas. With a strong sense of community and excellent schools, it’s ideal for families and outdoor enthusiasts."
#
# "Highland Park","1200000",4,3.5,"3500","This luxurious 4-bedroom, 3.5-bathroom home in Highland Park boasts high-end finishes, a gourmet kitchen with marble countertops, and a grand staircase. The master suite includes a fireplace, walk-in closet, and spa bathroom. The backyard features a pool and outdoor kitchen.","Highland Park is an upscale neighborhood known for its stately homes, manicured lawns, and proximity to elite schools and country clubs. Residents enjoy a quiet, prestigious lifestyle with easy access to downtown."
#
# "Willow Creek","495000",3,2,"1700","This cozy 3-bedroom, 2-bathroom home in Willow Creek features a newly renovated kitchen, hardwood floors, and a large backyard with mature trees. The open living and dining area is perfect for gatherings, and the primary suite includes a private bath.","Willow Creek is a peaceful suburban neighborhood with excellent schools, parks, and a strong sense of community. It’s ideal for young families and those seeking a quiet retreat from the city."
#
# "Lakeview","875000",4,3,"2800","Modern 4-bedroom, 3-bathroom home in Lakeview with lake access and stunning water views. The home features an open floor plan, floor-to-ceiling windows, and a large deck overlooking the lake. The kitchen includes quartz countertops and a walk-in pantry.","Lakeview is a scenic lakeside community offering boating, fishing, and waterfront dining. With its tranquil setting and recreational opportunities, it’s a favorite for nature lovers and retirees."
#
# "Old Town","650000",2,2,"1600","Historic charm meets modern convenience in this 2-bedroom, 2-bathroom bungalow in Old Town. Original hardwood floors, exposed brick, and a clawfoot tub add character, while the updated kitchen and HVAC system provide comfort.","Old Town is a vibrant, walkable neighborhood filled with historic homes, art galleries, and local cafes. Its rich history and cultural events make it a popular spot for creatives and professionals."
#
# "Meadow Ridge","715000",4,2.5,"2300","Spacious 4-bedroom, 2.5-bathroom home in Meadow Ridge with a large backyard and open-concept living area. The kitchen features stainless steel appliances and a breakfast nook. Upstairs, the master suite includes a soaking tub and walk-in closet.","Meadow Ridge is a growing suburban community with excellent schools, new shopping centers, and family-friendly parks. It’s perfect for those seeking a balance of convenience and tranquility."
#
# "Northgate","540000",3,2,"1900","This well-maintained 3-bedroom, 2-bathroom home in Northgate offers a bright and airy layout with vaulted ceilings and a gas fireplace. The kitchen has been updated with granite countertops and new appliances. The backyard includes a covered patio and garden beds.","Northgate is a quiet, established neighborhood with easy access to highways, shopping, and public transit. Known for its safety and community spirit, it’s a great place to raise a family or settle down."

# %%
# Convert the CSV string to a DataFrame
df_listings = pd.read_csv(StringIO(response))
df_listings
# Out:
#     Neighborhood    Price  Bedrooms  Bathrooms  House Size  \
# 0      Maplewood   675000         4        3.0        2400
# 1      Brookside   950000         5        4.0        3200
# 2   Sunset Hills   725000         3        2.5        2100
# 3      Riverbend   580000         3        2.0        1850
# 4  Highland Park  1200000         4        3.5        3500
# 5   Willow Creek   495000         3        2.0        1700
# 6       Lakeview   875000         4        3.0        2800
# 7       Old Town   650000         2        2.0        1600
# 8   Meadow Ridge   715000         4        2.5        2300
# 9      Northgate   540000         3        2.0        1900
#
#                                          Description  \
# 0  This beautifully updated 4-bedroom, 3-bathroom...
# 1  This stunning 5-bedroom, 4-bathroom home in Br...
# 2  Enjoy panoramic views in this 3-bedroom, 2.5-b...
# 3  Charming 3-bedroom, 2-bathroom ranch-style hom...
# 4  This luxurious 4-bedroom, 3.5-bathroom home in...
# 5  This cozy 3-bedroom, 2-bathroom home in Willow...
# 6  Modern 4-bedroom, 3-bathroom home in Lakeview ...
# 7  Historic charm meets modern convenience in thi...
# 8  Spacious 4-bedroom, 2.5-bathroom home in Meado...
# 9  This well-maintained 3-bedroom, 2-bathroom hom...
#
#                             Neighborhood Description
# 0  Maplewood is a family-friendly neighborhood kn...
# 1  Brookside is a historic neighborhood with a vi...
# 2  Sunset Hills is known for its scenic vistas, q...
# 3  Riverbend is a picturesque neighborhood along ...
# 4  Highland Park is an upscale neighborhood known...
# 5  Willow Creek is a peaceful suburban neighborho...
# 6  Lakeview is a scenic lakeside community offeri...
# 7  Old Town is a vibrant, walkable neighborhood f...
# 8  Meadow Ridge is a growing suburban community w...
# 9  Northgate is a quiet, established neighborhood...

# %%
# Save the DataFrame to a CSV file
df_listings.to_csv("data/real_estate_listings.csv", index=False)

# %% [markdown]
# ## Storing Listings in a Vector Database

# %%
def store_listings_in_vector_db(df_listing: pd.DataFrame)->Chroma:
    """"
    Store real estate listings in a vector database using Langchain and OpenAI."
    """

    # Combine the relevant fields into one document string for each listing
    def create_document(row):
        return (
            f"Neighborhood: {row['Neighborhood']}\n"
            f"Price: {row['Price']}\n"
            f"Bedrooms: {row['Bedrooms']}\n"
            f"Bathrooms: {row['Bathrooms']}\n"
            f"House Size: {row['House Size']}\n"
            f"Description: {row['Description']}\n"
            f"Neighborhood Description: {row['Neighborhood Description']}"
        )

    # Create a list of document texts
    documents = df_listing.apply(create_document, axis=1).tolist()

    # Use the row data as metadata for each document
    metadatas = df_listing.to_dict(orient="records")

    # Initialize OpenAIEmbeddings from Langchain
    embeddings = OpenAIEmbeddings()

    # Initialize the Chroma vector database collection with persistent storage.
    vectorstore = Chroma.from_texts(
        texts=documents,
        embedding=embeddings,
        metadatas=metadatas,
        collection_name="real_estate_listings",
    )

    return vectorstore

# %%
try: 
    # Store the listings in the vector database
    vectorstore = store_listings_in_vector_db(df_listings)
    print("Listings have been successfully stored in the vector database.")
except Exception as e:
    print(f"An error occurred while storing listings in the vector database: {e}")

# %% [markdown]
# ## Load the List of User Preferences

# %%
# Load the buyer preferences CSV file into a DataFrame
df_preference = pd.read_csv("data/buyer_preferences.csv")
df_preference
# Out:
#                                           Preference
# 0  Interested in homes under $500,000 in suburban...
# 1  Looking for properties in the $600,000 to $700...
# 2  Want a family-friendly community with access t...
# 3  Looking for a waterfront lifestyle, ideal for ...
# 4  Looking for homes with at least 3 bedrooms and...
# 5  Prefer 4+ bedrooms for a larger family in Broo...
# 6  Prefer modern features like updated kitchens, ...
# 7  Interested in luxury features like chef's kitc...
# 8  Attracted to homes with 2000 to 2400 sqft for ...

# %%
buyer_preferences = df_preference['Preference'].to_list()

# %% [markdown]
# ## Preference Search

# %% [markdown]
# Using [Langchain's self-querying retriever](https://python.langchain.com/docs/how_to/self_query/) that uses both semantic search and metadata filtering.

# %%
def get_retrievers(vectorstore:Chroma)->SelfQueryRetriever:
    """
    Get real estate recommendations based on buyer preferences using Langchain and OpenAI."
    """

    # Metadata fields of the real estate listings
    metadata_field_info = [
        AttributeInfo(name="Neighborhood", description="The neighborhood where the property is located.", type="string"),
        AttributeInfo(name="Price", description="The price of the property.", type="integer"),
        AttributeInfo(name="Bedrooms", description="The number of bedrooms in the property.", type="integer"),
        AttributeInfo(name="Bathrooms", description="The number of bathrooms in the property.", type="float"),
        AttributeInfo(name="House Size", description="The size of the house in square feet.", type="integer"),
        AttributeInfo(name="Description", description="A description of the property.", type="string"),
        AttributeInfo(name="NeighborhoodDescription", description="A description of the neighborhood.", type="string"),
    ] 

    document_content_description = "Real Estate Listings: Each listing contains information about the property, including neighborhood, price, number of bedrooms and bathrooms, house size, description, and neighborhood description."
    # Use a lower temperature for more deterministic output
    llm = ChatOpenAI(model_name = "chatgpt-4o-latest", temperature=0.2)

    retriever = SelfQueryRetriever.from_llm(
        llm, vectorstore, document_content_description, metadata_field_info, verbose=True)
    
    return retriever

# %%
# Test the retriever with a sample buyer preference

retriever = get_retrievers(vectorstore)

i=2
print(buyer_preferences[i])
similar_listings = retriever.invoke(buyer_preferences[i])
print(similar_listings[0].page_content)
# Out:
# Want a family-friendly community with access to parks, events, and top schools
# Neighborhood: Maplewood
# Price: 675000
# Bedrooms: 4
# Bathrooms: 3.0
# House Size: 2400
# Description: This beautifully updated 4-bedroom, 3-bathroom home in Maplewood offers spacious living with modern finishes. The open-concept kitchen features granite countertops, stainless steel appliances, and a large island perfect for entertaining. A cozy fireplace anchors the living room, while the master suite includes a walk-in closet and spa-like bathroom. The backyard is fully fenced with a patio ideal for summer barbecues.
# Neighborhood Description: Maplewood is a family-friendly neighborhood known for its tree-lined streets, excellent schools, and community events. Residents enjoy weekend farmers markets, local parks, and a variety of dining options within walking distance.

# %% [markdown]
# ## Personalizing Listing Descriptions

# %%
def generate_personalized_listing_description(buyer_preference:str, retriever:SelfQueryRetriever)-> str:
    """
    Generate a personalized listing description based on the buyer's preference and the listing details.
    """

    # Define the prompt template to generate a personalized listing description.
    prompt_template = """
    You are a creative real estate assistant. Given the following listing details and a buyer's preference, generate a personalized listing description that highlights the aspects of the property aligning with the buyer's preferences, while preserving all factual details about the property. Do not modify any factual information.

    Listing:
    {listing}

    Buyer Preference:
    {buyer_preference}

    Personalized Description:
    """

    # Create a PromptTemplate object with two input variables.
    prompt = PromptTemplate(
        input_variables=["listing", "buyer_preference"],
        template=prompt_template
    )

    # Initialize the OpenAI LLM (adjust the temperature as needed for creativity)
    llm = ChatOpenAI(model_name = "chatgpt-4o-latest", temperature=0.7)

    # Create an LLMChain to combine the prompt and LLM.
    chain = LLMChain(llm=llm, prompt=prompt)

    similar_listings = retriever.invoke(buyer_preference)

    if not similar_listings:
        print("No similar listings found. Please try again with a different preference.")
        return None
    
    # Generate the personalized description using the LLMChain.
    listing = similar_listings[0].page_content
    print("Cloest match listing:")
    print(listing)

    personalized_description = chain.run(
        listing=listing,
        buyer_preference=buyer_preference
    )

    return personalized_description

# %%
# Test the function with the buyer preferences

for i in range(len(buyer_preferences)):
    buyer_preference = buyer_preferences[i]
    print("----------------------------------------------------------------------------------------------------")
    print(buyer_preference)
    personalized_description = generate_personalized_listing_description(buyer_preference, retriever)
    print('\n')
    print(personalized_description)
# Out:
# ----------------------------------------------------------------------------------------------------
# Interested in homes under $500,000 in suburban neighborhoods
# Cloest match listing:
# Neighborhood: Willow Creek
# Price: 495000
# Bedrooms: 3
# Bathrooms: 2.0
# House Size: 1700
# Description: This cozy 3-bedroom, 2-bathroom home in Willow Creek features a newly renovated kitchen, hardwood floors, and a large backyard with mature trees. The open living and dining area is perfect for gatherings, and the primary suite includes a private bath.
# Neighborhood Description: Willow Creek is a peaceful suburban neighborhood with excellent schools, parks, and a strong sense of community. It’s ideal for young families and those seeking a quiet retreat from the city.
#
#
# Welcome to your perfect retreat in the heart of Willow Creek! Priced at $495,000, this charming 3-bedroom, 2-bathroom home offers 1,700 square feet of thoughtfully designed living space—ideal for creating lasting memories. Step into the newly renovated kitchen, where modern touches meet everyday functionality, and enjoy the warmth of hardwood floors that flow throughout the open living and dining area—perfect for hosting friends or relaxing with family.
#
# The spacious primary suite provides a tranquil escape with its own private bath, while the large backyard, shaded by mature trees, invites outdoor play, weekend barbecues, or quiet mornings with coffee and birdsong.
#
# Nestled in a peaceful suburban setting, Willow Creek offers excellent schools, nearby parks, and a welcoming community atmosphere—making it an ideal location for those looking to embrace a quieter lifestyle without sacrificing convenience. This home is a great match for anyone seeking comfort, style, and a sense of belonging.
# ----------------------------------------------------------------------------------------------------
# Looking for properties in the $600,000 to $700,000 range with updated interiors and good neighborhood amenities
# Cloest match listing:
# Neighborhood: Old Town
# Price: 650000
# Bedrooms: 2
# Bathrooms: 2.0
# House Size: 1600
# Description: Historic charm meets modern convenience in this 2-bedroom, 2-bathroom bungalow in Old Town. Original hardwood floors, exposed brick, and a clawfoot tub add character, while the updated kitchen and HVAC system provide comfort.
# Neighborhood Description: Old Town is a vibrant, walkable neighborhood filled with historic homes, art galleries, and local cafes. Its rich history and cultural events make it a popular spot for creatives and professionals.
#
#
# Personalized Description:
# Step into timeless elegance with this 2-bedroom, 2-bathroom bungalow nestled in the heart of Old Town—an ideal match for those who appreciate both character and convenience. With 1,600 square feet of thoughtfully designed space, this home offers original hardwood floors, exposed brick accents, and a classic clawfoot tub that speaks to its historic roots. The updated kitchen and modern HVAC system ensure you won’t sacrifice comfort for charm.
# ----------------------------------------------------------------------------------------------------
# Looking for homes with at least 3 bedrooms and 2 bathrooms
# Cloest match listing:
# Neighborhood: Sunset Hills
# Price: 725000
# Bedrooms: 3
# Bathrooms: 2.5
# House Size: 2100
# Description: Enjoy panoramic views in this 3-bedroom, 2.5-bathroom home perched in Sunset Hills. The open floor plan includes a gourmet kitchen, vaulted ceilings, and a sunroom that opens to a large deck. The master suite features a private balcony and luxurious en-suite bathroom.
# Neighborhood Description: Sunset Hills is known for its scenic vistas, quiet streets, and upscale homes. Residents enjoy hiking trails, nearby wineries, and a peaceful suburban atmosphere just minutes from the city center.
#
#
# Personalized Description:
# Nestled in the serene and scenic neighborhood of Sunset Hills, this stunning 3-bedroom, 2.5-bathroom home offers the perfect blend of elegance and tranquility—ideal for a buyer seeking inspiring views and a peaceful suburban setting. With an expansive 2,100 square feet, the open floor plan is designed for both everyday living and entertaining. The gourmet kitchen flows seamlessly into vaulted-ceiling living spaces and a sunroom that opens onto a spacious deck—perfect for enjoying morning coffee or evening sunsets.
#
# The master suite is a true retreat, featuring its own private balcony and a luxurious en-suite bathroom. Whether you're unwinding indoors or stepping out to explore nearby hiking trails and local wineries, this home offers the elevated lifestyle you’ve been looking for—all just minutes from the city center.
#
# Experience the best of Sunset Hills living at $725,000—where panoramic views and upscale comfort come together beautifully.
# ----------------------------------------------------------------------------------------------------
# Prefer 4+ bedrooms for a larger family in Brookside
# Cloest match listing:
# Neighborhood: Brookside
# Price: 950000
# Bedrooms: 5
# Bathrooms: 4.0
# House Size: 3200
# Description: This stunning 5-bedroom, 4-bathroom home in Brookside combines classic charm with modern upgrades. Featuring hardwood floors throughout, a chef’s kitchen with double ovens, and a finished basement with a home theater, this home is perfect for large families or entertaining guests. The landscaped backyard includes a pergola and fire pit.
# Neighborhood Description: Brookside is a historic neighborhood with a vibrant arts scene, boutique shopping, and top-rated restaurants. Its walkable streets and proximity to downtown make it a favorite among professionals and families alike.
#
#
# Step into timeless elegance in the heart of Brookside with this spacious 5-bedroom, 4-bathroom home—a perfect match for those seeking room to grow and entertain in style. With 3,200 square feet of beautifully appointed living space, this residence offers classic hardwood floors throughout and a chef’s kitchen equipped with double ovens, ideal for preparing meals and hosting gatherings.
#
# The finished basement features a home theater, creating an inviting space for movie nights or weekend get-togethers. Outside, the landscaped backyard with a pergola and fire pit invites year-round enjoyment and relaxation.
#
# Nestled in the historic and walkable Brookside neighborhood, this home offers access to a vibrant arts scene, boutique shopping, and top-rated restaurants—all just minutes from downtown. Whether you're expanding your family or love to entertain, this Brookside gem delivers comfort, convenience, and character. Priced at $950,000, it’s ready to welcome you home.
# ----------------------------------------------------------------------------------------------------
# Prefer modern features like updated kitchens, open-concept layouts, and fenced backyards.
# Cloest match listing:
# Neighborhood: Maplewood
# Price: 675000
# Bedrooms: 4
# Bathrooms: 3.0
# House Size: 2400
# Description: This beautifully updated 4-bedroom, 3-bathroom home in Maplewood offers spacious living with modern finishes. The open-concept kitchen features granite countertops, stainless steel appliances, and a large island perfect for entertaining. A cozy fireplace anchors the living room, while the master suite includes a walk-in closet and spa-like bathroom. The backyard is fully fenced with a patio ideal for summer barbecues.
# Neighborhood Description: Maplewood is a family-friendly neighborhood known for its tree-lined streets, excellent schools, and community events. Residents enjoy weekend farmers markets, local parks, and a variety of dining options within walking distance.
#
#
# Experience the perfect blend of comfort and community in this beautifully updated 4-bedroom, 3-bathroom home nestled in the heart of Maplewood. With 2,400 square feet of thoughtfully designed space, this residence caters to those who value modern finishes and functional design. The open-concept kitchen—complete with granite countertops, stainless steel appliances, and a generous island—offers an inviting space for gathering and entertaining. Unwind by the cozy fireplace in the spacious living room, or retreat to the master suite featuring a walk-in closet and a spa-like bathroom for well-deserved relaxation.
#
# Step outside to a fully fenced backyard with a patio, ideal for summer barbecues or playtime with loved ones. Located in Maplewood, a family-friendly neighborhood known for its tree-lined streets, top-rated schools, and vibrant community spirit, you'll enjoy weekend farmers markets, neighborhood parks, and walkable dining options. This home offers the lifestyle you’ve been looking for—modern living in a warm, welcoming community. Priced at $675,000, it’s ready to welcome you home.

# %% [markdown]
# ## Test a different buyer preference

# %%
buyer_preference = "I am looking for a modern home with at least 4 bedrooms and a spacious backyard, preferably in a family-friendly neighborhood with good schools."

print(buyer_preference)
personalized_description = generate_personalized_listing_description(buyer_preference, retriever)
print('\n')
print(personalized_description)
# Out:
# I am looking for a modern home with at least 4 bedrooms and a spacious backyard, preferably in a family-friendly neighborhood with good schools.
# Cloest match listing:
# Neighborhood: Maplewood
# Price: 675000
# Bedrooms: 4
# Bathrooms: 3.0
# House Size: 2400
# Description: This beautifully updated 4-bedroom, 3-bathroom home in Maplewood offers spacious living with modern finishes. The open-concept kitchen features granite countertops, stainless steel appliances, and a large island perfect for entertaining. A cozy fireplace anchors the living room, while the master suite includes a walk-in closet and spa-like bathroom. The backyard is fully fenced with a patio ideal for summer barbecues.
# Neighborhood Description: Maplewood is a family-friendly neighborhood known for its tree-lined streets, excellent schools, and community events. Residents enjoy weekend farmers markets, local parks, and a variety of dining options within walking distance.
#
#
# Welcome to your ideal home in the heart of Maplewood—a family-friendly neighborhood known for its tree-lined streets, top-rated schools, and vibrant community spirit. This beautifully updated 4-bedroom, 3-bathroom residence offers 2,400 square feet of spacious living designed for both comfort and style.
#
# Step into the open-concept kitchen, where granite countertops, stainless steel appliances, and a large island create the perfect space for both casual meals and lively entertaining. The adjoining living room, anchored by a cozy fireplace, provides a warm gathering place for family and guests alike.
#
# The master suite is a true retreat, featuring a generous walk-in closet and a spa-like bathroom ideal for unwinding after a long day. Outdoors, the fully fenced backyard with a patio offers a safe and inviting space for summer barbecues and weekend relaxation.
#
# Living in Maplewood means more than just a beautiful home—it’s access to weekend farmers markets, local parks, and a variety of dining options just a short walk away. This home blends modern comforts with the welcoming charm of a close-knit community, making it a perfect match for your lifestyle.
